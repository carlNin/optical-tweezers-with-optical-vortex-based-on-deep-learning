# %% [raw]
# '''
# Training model
#
# Version: pytorch 1.13.1
# Author: LN
# '''

# %%
from torch import optim
import torch.utils.data as data
from setting_model import *
import numpy as np
import os
# Out:
# CUDA Device Count: 1
# CUDA Device Name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# Model instantiation
# forward_model = model
forward_model = FC_Net().to(device)

iteration = 0
interval = 100
batch_size = 20                 # 修改
lr = 3e-4
epoch = 2000
iter_num = []
losses = {'err_train': [], 'err_test': [], 'loss_train': [], 'loss_test': []}

# %%
# Gets the relevant file path
data_root = os.getcwd()
bo_len_path = os.path.join(data_root, "Train_Data_Fig4", "X.csv")
assert os.path.exists(bo_len_path), "{} path does not exist.".format(bo_len_path)                  # assert function

train_spectrum_path = os.path.join(data_root, "Train_Data_Fig4", "train_680.csv")
assert os.path.exists(train_spectrum_path), "{} path does not exist.".format(train_spectrum_path)

test_spectrum_path = os.path.join(data_root, "Train_Data_Fig4", "test_77.csv")
assert os.path.exists(test_spectrum_path), "{} path does not exist.".format(test_spectrum_path)

# Save the updated weights file
#save_dir = os.path.join(data_root, "weight_optim")
#assert os.path.exists(save_dir), "{} path does not exist.".format(save_dir)

# %%
# Loader Data
train_numpy = np.loadtxt(train_spectrum_path, delimiter=",")
train_input = torch.FloatTensor(train_numpy[:, 600:603]).to(device)
train_label = torch.FloatTensor(train_numpy[:, 0:300]).to(device)
train_dataset = data.TensorDataset(train_input, train_label)
data_loader = data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)    # 提取训练数据集并加载

test_numpy = np.loadtxt(test_spectrum_path, delimiter=",")
test_input = torch.FloatTensor(test_numpy[:, 600:603]).to(device)
test_label = torch.FloatTensor(test_numpy[:, 0:300]).to(device)                               # 提取测试数据集

# %%
train_input.shape, test_input.shape
# Out:
# (torch.Size([680, 3]), torch.Size([77, 3]))

# %%
# Training process
def train():
    optimizer = optim.Adam(forward_model.parameters(), lr=lr)
    criterion = nn.MSELoss(reduction='mean')

    for t in range(epoch):
        for step, item in enumerate(data_loader):
            # train
            train_input, train_label = item
            train_predict = forward_model(train_input)
            loss_train = criterion(train_predict, train_label)
            
            global iteration                      # 声明全局变量， 不声明全局变量会报错
            if iteration % interval == 0:
                # test
                test_predict = forward_model(test_input)
                loss_test = criterion(test_predict, test_label)
                losses['loss_train'].append(loss_train.cpu().detach().numpy())
                losses['loss_test'].append(loss_test.cpu().detach().numpy())

                # compute and print the absolute error
                train_out = train_predict - train_label
                train_error = np.abs(train_out.cpu().detach().numpy()).mean()
                test_out = test_predict - test_label
                test_error = np.abs(test_out.cpu().detach().numpy()).mean()
                losses['err_train'].append(train_error)
                losses['err_test'].append(test_error)

                print('iteration: {}'.format(iteration))
                print('train_loss: {:.4}, test_loss: {:.4}'.
                      format(loss_train, loss_test))
                print('train_error: {:.4}, test_error: {:.4}'.
                      format(train_error, test_error))

                iter_num.append(iteration)


            # update parameters
            optimizer.zero_grad()
            loss_train.backward()
            optimizer.step()

            iteration += 1

# %%
train()
# Out:
# iteration: 0
# train_loss: 7.531, test_loss: 19.91
# train_error: 1.587, test_error: 1.867
# iteration: 100
# train_loss: 1.417, test_loss: 3.332
# train_error: 0.7187, test_error: 0.9572
# iteration: 200
# train_loss: 3.682, test_loss: 2.751
# train_error: 1.195, test_error: 0.8854
# iteration: 300
# train_loss: 1.085, test_loss: 1.507
# train_error: 0.6811, test_error: 0.7429
# iteration: 400
# train_loss: 1.547, test_loss: 1.496
# train_error: 0.8016, test_error: 0.7075
# iteration: 500
# train_loss: 0.6603, test_loss: 1.075
# train_error: 0.4422, test_error: 0.6254
# iteration: 600
# train_loss: 1.395, test_loss: 0.9598
# train_error: 0.6476, test_error: 0.6016
# iteration: 700
# train_loss: 0.7657, test_loss: 0.7891
# train_error: 0.4926, test_error: 0.5408
# iteration: 800
# train_loss: 0.312, test_loss: 0.904
# train_error: 0.3744, test_error: 0.5352
# iteration: 900
# train_loss: 0.3322, test_loss: 0.5253
# train_error: 0.4026, test_error: 0.4194
# iteration: 1000
# train_loss: 0.2216, test_loss: 0.3595
# train_error: 0.3381, test_error: 0.36
# iteration: 1100
# train_loss: 0.1305, test_loss: 0.2868
# train_error: 0.237, test_error: 0.3234
# iteration: 1200
# train_loss: 0.27, test_loss: 0.9067
# train_error: 0.3569, test_error: 0.4754
# iteration: 1300
# train_loss: 0.2162, test_loss: 0.3003
# train_error: 0.3276, test_error: 0.3387
# iteration: 1400
# train_loss: 0.1522, test_loss: 0.3425
# train_error: 0.2692, test_error: 0.3381
# iteration: 1500
# train_loss: 0.1085, test_loss: 0.1951
# train_error: 0.2223, test_error: 0.2612
# iteration: 1600
# train_loss: 0.08266, test_loss: 0.1538
# train_error: 0.1959, test_error: 0.2483
# iteration: 1700
# train_loss: 0.07026, test_loss: 0.1245
# train_error: 0.178, test_error: 0.2211
# iteration: 1800
# train_loss: 0.07446, test_loss: 0.1147
# train_error: 0.1831, test_error: 0.2101
# iteration: 1900
# train_loss: 0.2027, test_loss: 0.7535
# train_error: 0.2749, test_error: 0.4366
# iteration: 2000
# train_loss: 0.232, test_loss: 0.6156
# train_error: 0.3007, test_error: 0.3795
# iteration: 2100
# train_loss: 0.1182, test_loss: 0.1537
# train_error: 0.2022, test_error: 0.2231
# iteration: 2200
# train_loss: 0.03798, test_loss: 0.09786
# train_error: 0.1409, test_error: 0.18
# iteration: 2300
# train_loss: 0.05464, test_loss: 0.1234
# train_error: 0.1596, test_error: 0.2026
# iteration: 2400
# train_loss: 0.01365, test_loss: 0.07983
# train_error: 0.08734, test_error: 0.1617
# iteration: 2500
# train_loss: 0.05231, test_loss: 0.1254
# train_error: 0.1653, test_error: 0.2082
# iteration: 2600
# train_loss: 0.02956, test_loss: 0.09963
# train_error: 0.1186, test_error: 0.1726
# iteration: 2700
# train_loss: 0.03916, test_loss: 0.07929
# train_error: 0.1426, test_error: 0.1766
# iteration: 2800
# train_loss: 0.733, test_loss: 1.347
# train_error: 0.4806, test_error: 0.5486
# iteration: 2900
# train_loss: 0.4331, test_loss: 0.2917
# train_error: 0.3576, test_error: 0.3127
# iteration: 3000
# train_loss: 0.03962, test_loss: 0.07489
# train_error: 0.1331, test_error: 0.1564
# iteration: 3100
# train_loss: 0.01802, test_loss: 0.06789
# train_error: 0.093, test_error: 0.1444
# iteration: 3200
# train_loss: 0.01316, test_loss: 0.05402
# train_error: 0.08151, test_error: 0.1263
# iteration: 3300
# train_loss: 0.01806, test_loss: 0.05573
# train_error: 0.09739, test_error: 0.1284
# iteration: 3400
# train_loss: 0.01227, test_loss: 0.05269
# train_error: 0.08189, test_error: 0.1224
# iteration: 3500
# train_loss: 0.0329, test_loss: 0.06152
# train_error: 0.126, test_error: 0.1396
# iteration: 3600
# train_loss: 0.1541, test_loss: 0.1422
# train_error: 0.2429, test_error: 0.198
# iteration: 3700
# train_loss: 0.09759, test_loss: 0.1593
# train_error: 0.2027, test_error: 0.2237
# iteration: 3800
# train_loss: 0.02464, test_loss: 0.06205
# train_error: 0.1121, test_error: 0.141
# iteration: 3900
# train_loss: 0.02721, test_loss: 0.07418
# train_error: 0.111, test_error: 0.16
# iteration: 4000
# train_loss: 0.03699, test_loss: 0.05935
# train_error: 0.1291, test_error: 0.1353
# iteration: 4100
# train_loss: 0.06464, test_loss: 0.5582
# train_error: 0.1805, test_error: 0.3139
# iteration: 4200
# train_loss: 0.1499, test_loss: 0.5071
# train_error: 0.275, test_error: 0.3643
# iteration: 4300
# train_loss: 0.03308, test_loss: 0.1907
# train_error: 0.1036, test_error: 0.2088
# iteration: 4400
# train_loss: 0.02189, test_loss: 0.06369
# train_error: 0.1042, test_error: 0.1351
# iteration: 4500
# train_loss: 0.03299, test_loss: 0.05374
# train_error: 0.1056, test_error: 0.1173
# iteration: 4600
# train_loss: 0.03546, test_loss: 0.07021
# train_error: 0.1179, test_error: 0.1377
# iteration: 4700
# train_loss: 0.05412, test_loss: 0.2216
# train_error: 0.1532, test_error: 0.1944
# iteration: 4800
# train_loss: 0.01306, test_loss: 0.0444
# train_error: 0.08389, test_error: 0.1085
# iteration: 4900
# train_loss: 0.07821, test_loss: 0.1217
# train_error: 0.1625, test_error: 0.1896
# iteration: 5000
# train_loss: 0.01174, test_loss: 0.04282
# train_error: 0.07241, test_error: 0.1086
# iteration: 5100
# train_loss: 0.3417, test_loss: 0.2853
# train_error: 0.2329, test_error: 0.1962
# iteration: 5200
# train_loss: 0.02827, test_loss: 0.06568
# train_error: 0.1137, test_error: 0.1431
# iteration: 5300
# train_loss: 0.0251, test_loss: 0.06207
# train_error: 0.1007, test_error: 0.1252
# iteration: 5400
# train_loss: 0.009423, test_loss: 0.04195
# train_error: 0.06962, test_error: 0.1014
# iteration: 5500
# train_loss: 0.07237, test_loss: 0.3127
# train_error: 0.1675, test_error: 0.2828
# iteration: 5600
# train_loss: 0.3936, test_loss: 0.2994
# train_error: 0.4112, test_error: 0.3173
# iteration: 5700
# train_loss: 0.04657, test_loss: 0.2446
# train_error: 0.1389, test_error: 0.1923
# iteration: 5800
# train_loss: 0.00822, test_loss: 0.03942
# train_error: 0.06606, test_error: 0.1069
# iteration: 5900
# train_loss: 0.07087, test_loss: 0.09977
# train_error: 0.1394, test_error: 0.1728
# iteration: 6000
# train_loss: 0.007458, test_loss: 0.05016
# train_error: 0.06356, test_error: 0.1065
# iteration: 6100
# train_loss: 0.006272, test_loss: 0.02877
# train_error: 0.05561, test_error: 0.09159
# iteration: 6200
# train_loss: 0.005992, test_loss: 0.02923
# train_error: 0.05288, test_error: 0.08257
# iteration: 6300
# train_loss: 0.00382, test_loss: 0.02399
# train_error: 0.04579, test_error: 0.07691
# iteration: 6400
# train_loss: 0.009547, test_loss: 0.02861
# train_error: 0.07033, test_error: 0.08595
# iteration: 6500
# train_loss: 0.00833, test_loss: 0.04669
# train_error: 0.06049, test_error: 0.09539
# iteration: 6600
# train_loss: 0.0124, test_loss: 0.04467
# train_error: 0.072, test_error: 0.1072
# iteration: 6700
# train_loss: 0.1189, test_loss: 0.1452
# train_error: 0.2097, test_error: 0.194
# iteration: 6800
# train_loss: 0.07922, test_loss: 0.1953
# train_error: 0.1854, test_error: 0.243
# iteration: 6900
# train_loss: 0.0467, test_loss: 0.06681
# train_error: 0.1049, test_error: 0.1272
# iteration: 7000
# train_loss: 0.08873, test_loss: 0.2106
# train_error: 0.1833, test_error: 0.2165
# iteration: 7100
# train_loss: 0.01271, test_loss: 0.04332
# train_error: 0.07152, test_error: 0.1102
# iteration: 7200
# train_loss: 0.02706, test_loss: 0.1697
# train_error: 0.1024, test_error: 0.2002
# iteration: 7300
# train_loss: 0.006851, test_loss: 0.03347
# train_error: 0.05644, test_error: 0.09122
# iteration: 7400
# train_loss: 0.008833, test_loss: 0.0273
# train_error: 0.06013, test_error: 0.08521
# iteration: 7500
# train_loss: 0.008257, test_loss: 0.04169
# train_error: 0.06486, test_error: 0.1037
# iteration: 7600
# train_loss: 0.01186, test_loss: 0.02723
# train_error: 0.07319, test_error: 0.08419
# iteration: 7700
# train_loss: 0.01309, test_loss: 0.05631
# train_error: 0.07486, test_error: 0.112
# iteration: 7800
# train_loss: 0.197, test_loss: 0.3403
# train_error: 0.2673, test_error: 0.3265
# iteration: 7900
# train_loss: 0.01893, test_loss: 0.09644
# train_error: 0.09308, test_error: 0.1399
# iteration: 8000
# train_loss: 0.005594, test_loss: 0.03118
# train_error: 0.0527, test_error: 0.0821
# iteration: 8100
# train_loss: 0.007952, test_loss: 0.0228
# train_error: 0.06006, test_error: 0.07719
# iteration: 8200
# train_loss: 0.004388, test_loss: 0.02823
# train_error: 0.04936, test_error: 0.07599
# iteration: 8300
# train_loss: 0.002897, test_loss: 0.02562
# train_error: 0.03739, test_error: 0.07279
# iteration: 8400
# train_loss: 0.01943, test_loss: 0.07608
# train_error: 0.07608, test_error: 0.131
# iteration: 8500
# train_loss: 0.007146, test_loss: 0.02693
# train_error: 0.05559, test_error: 0.08247
# iteration: 8600
# train_loss: 0.002796, test_loss: 0.02802
# train_error: 0.03834, test_error: 0.06915
# iteration: 8700
# train_loss: 0.01556, test_loss: 0.05584
# train_error: 0.07567, test_error: 0.1159
# iteration: 8800
# train_loss: 0.01032, test_loss: 0.03068
# train_error: 0.06523, test_error: 0.0965
# iteration: 8900
# train_loss: 0.005784, test_loss: 0.03818
# train_error: 0.0525, test_error: 0.09317
# iteration: 9000
# train_loss: 0.07624, test_loss: 0.1858
# train_error: 0.1829, test_error: 0.1991
# iteration: 9100
# train_loss: 0.058, test_loss: 0.05946
# train_error: 0.1281, test_error: 0.139
# iteration: 9200
# train_loss: 0.00938, test_loss: 0.02543
# train_error: 0.06615, test_error: 0.08697
# iteration: 9300
# train_loss: 0.01125, test_loss: 0.07735
# train_error: 0.07335, test_error: 0.1195
# iteration: 9400
# train_loss: 0.2681, test_loss: 0.3265
# train_error: 0.2356, test_error: 0.2212
# iteration: 9500
# train_loss: 0.0215, test_loss: 0.1147
# train_error: 0.09669, test_error: 0.1628
# iteration: 9600
# train_loss: 0.02046, test_loss: 0.06112
# train_error: 0.07715, test_error: 0.1174
# iteration: 9700
# train_loss: 0.08386, test_loss: 0.1966
# train_error: 0.1207, test_error: 0.1887
# iteration: 9800
# train_loss: 0.02173, test_loss: 0.04981
# train_error: 0.08202, test_error: 0.09583
# iteration: 9900
# train_loss: 0.009117, test_loss: 0.036
# train_error: 0.05943, test_error: 0.08542
# iteration: 10000
# train_loss: 0.004877, test_loss: 0.02624
# train_error: 0.04813, test_error: 0.07127
# iteration: 10100
# train_loss: 0.01092, test_loss: 0.02331
# train_error: 0.0736, test_error: 0.0729
# iteration: 10200
# train_loss: 0.01252, test_loss: 0.03775
# train_error: 0.07388, test_error: 0.09292
# iteration: 10300
# train_loss: 0.008742, test_loss: 0.03132
# train_error: 0.06485, test_error: 0.09339
# iteration: 10400
# train_loss: 0.002736, test_loss: 0.02141
# train_error: 0.0374, test_error: 0.06287
# iteration: 10500
# train_loss: 0.02041, test_loss: 0.03613
# train_error: 0.08537, test_error: 0.1012
# iteration: 10600
# train_loss: 0.008981, test_loss: 0.03263
# train_error: 0.06292, test_error: 0.08217
# iteration: 10700
# train_loss: 0.4424, test_loss: 0.3749
# train_error: 0.3952, test_error: 0.3423
# iteration: 10800
# train_loss: 0.2601, test_loss: 0.1603
# train_error: 0.2647, test_error: 0.2344
# iteration: 10900
# train_loss: 0.005406, test_loss: 0.04788
# train_error: 0.05527, test_error: 0.1084
# iteration: 11000
# train_loss: 0.01183, test_loss: 0.02479
# train_error: 0.07576, test_error: 0.08081
# iteration: 11100
# train_loss: 0.005064, test_loss: 0.02272
# train_error: 0.0472, test_error: 0.07759
# iteration: 11200
# train_loss: 0.007463, test_loss: 0.02125
# train_error: 0.0571, test_error: 0.07002
# iteration: 11300
# train_loss: 0.002323, test_loss: 0.02188
# train_error: 0.03388, test_error: 0.06764
# iteration: 11400
# train_loss: 0.00314, test_loss: 0.01889
# train_error: 0.03912, test_error: 0.06368
# iteration: 11500
# train_loss: 0.001986, test_loss: 0.0172
# train_error: 0.03381, test_error: 0.06017
# iteration: 11600
# train_loss: 0.002091, test_loss: 0.02401
# train_error: 0.03483, test_error: 0.06976
# iteration: 11700
# train_loss: 0.002936, test_loss: 0.0173
# train_error: 0.0404, test_error: 0.06269
# iteration: 11800
# train_loss: 0.003122, test_loss: 0.0218
# train_error: 0.04124, test_error: 0.0665
# iteration: 11900
# train_loss: 0.002956, test_loss: 0.01801
# train_error: 0.04061, test_error: 0.06142
# iteration: 12000
# train_loss: 0.02115, test_loss: 0.06871
# train_error: 0.09555, test_error: 0.139
# iteration: 12100
# train_loss: 0.2522, test_loss: 0.2674
# train_error: 0.1947, test_error: 0.1795
# iteration: 12200
# train_loss: 0.02896, test_loss: 0.06158
# train_error: 0.1025, test_error: 0.1244
# iteration: 12300
# train_loss: 0.008816, test_loss: 0.036
# train_error: 0.05869, test_error: 0.08976
# iteration: 12400
# train_loss: 0.002889, test_loss: 0.02439
# train_error: 0.03955, test_error: 0.06921
# iteration: 12500
# train_loss: 0.002988, test_loss: 0.02422
# train_error: 0.03976, test_error: 0.06523
# iteration: 12600
# train_loss: 0.01246, test_loss: 0.04332
# train_error: 0.06886, test_error: 0.1112
# iteration: 12700
# train_loss: 0.003616, test_loss: 0.02322
# train_error: 0.04102, test_error: 0.06829
# iteration: 12800
# train_loss: 0.001857, test_loss: 0.02136
# train_error: 0.03042, test_error: 0.05933
# iteration: 12900
# train_loss: 0.01093, test_loss: 0.03279
# train_error: 0.05764, test_error: 0.08147
# iteration: 13000
# train_loss: 0.005651, test_loss: 0.02638
# train_error: 0.04644, test_error: 0.07999
# iteration: 13100
# train_loss: 0.00579, test_loss: 0.02435
# train_error: 0.04862, test_error: 0.06998
# iteration: 13200
# train_loss: 0.356, test_loss: 0.3008
# train_error: 0.3762, test_error: 0.2634
# iteration: 13300
# train_loss: 0.02415, test_loss: 0.03559
# train_error: 0.08377, test_error: 0.09431
# iteration: 13400
# train_loss: 0.009023, test_loss: 0.01819
# train_error: 0.06398, test_error: 0.06773
# iteration: 13500
# train_loss: 0.006633, test_loss: 0.05199
# train_error: 0.05509, test_error: 0.1013
# iteration: 13600
# train_loss: 0.007712, test_loss: 0.03397
# train_error: 0.05881, test_error: 0.09121
# iteration: 13700
# train_loss: 0.008572, test_loss: 0.02995
# train_error: 0.05034, test_error: 0.06936
# iteration: 13800
# train_loss: 0.08086, test_loss: 0.07478
# train_error: 0.1276, test_error: 0.1231
# iteration: 13900
# train_loss: 0.03928, test_loss: 0.08088
# train_error: 0.1116, test_error: 0.1426
# iteration: 14000
# train_loss: 0.02103, test_loss: 0.0363
# train_error: 0.09204, test_error: 0.08865
# iteration: 14100
# train_loss: 0.006341, test_loss: 0.05555
# train_error: 0.05694, test_error: 0.1083
# iteration: 14200
# train_loss: 0.04033, test_loss: 0.1783
# train_error: 0.1321, test_error: 0.1713
# iteration: 14300
# train_loss: 0.03468, test_loss: 0.04439
# train_error: 0.06549, test_error: 0.08763
# iteration: 14400
# train_loss: 0.09382, test_loss: 0.2728
# train_error: 0.1784, test_error: 0.2789
# iteration: 14500
# train_loss: 0.06512, test_loss: 0.06523
# train_error: 0.1214, test_error: 0.108
# iteration: 14600
# train_loss: 0.003034, test_loss: 0.02463
# train_error: 0.04039, test_error: 0.0678
# iteration: 14700
# train_loss: 0.001669, test_loss: 0.02115
# train_error: 0.02993, test_error: 0.05908
# iteration: 14800
# train_loss: 0.005426, test_loss: 0.02491
# train_error: 0.04168, test_error: 0.06234
# iteration: 14900
# train_loss: 0.001626, test_loss: 0.01803
# train_error: 0.0293, test_error: 0.05519
# iteration: 15000
# train_loss: 0.002007, test_loss: 0.0204
# train_error: 0.03216, test_error: 0.0601
# iteration: 15100
# train_loss: 0.002355, test_loss: 0.02241
# train_error: 0.03356, test_error: 0.05585
# iteration: 15200
# train_loss: 0.00248, test_loss: 0.01908
# train_error: 0.03272, test_error: 0.05403
# iteration: 15300
# train_loss: 0.006529, test_loss: 0.02254
# train_error: 0.05214, test_error: 0.07058
# iteration: 15400
# train_loss: 0.02572, test_loss: 0.05694
# train_error: 0.08313, test_error: 0.132
# iteration: 15500
# train_loss: 0.08446, test_loss: 0.1143
# train_error: 0.1787, test_error: 0.1856
# iteration: 15600
# train_loss: 0.007573, test_loss: 0.04108
# train_error: 0.05319, test_error: 0.09159
# iteration: 15700
# train_loss: 0.01206, test_loss: 0.03852
# train_error: 0.06988, test_error: 0.08318
# iteration: 15800
# train_loss: 0.004652, test_loss: 0.03949
# train_error: 0.04052, test_error: 0.07486
# iteration: 15900
# train_loss: 0.003649, test_loss: 0.02647
# train_error: 0.03785, test_error: 0.06171
# iteration: 16000
# train_loss: 0.009514, test_loss: 0.02467
# train_error: 0.06047, test_error: 0.06541
# iteration: 16100
# train_loss: 0.009587, test_loss: 0.04078
# train_error: 0.06171, test_error: 0.09111
# iteration: 16200
# train_loss: 0.00692, test_loss: 0.07012
# train_error: 0.05206, test_error: 0.1021
# iteration: 16300
# train_loss: 0.005098, test_loss: 0.03221
# train_error: 0.0504, test_error: 0.0843
# iteration: 16400
# train_loss: 0.002203, test_loss: 0.02865
# train_error: 0.03575, test_error: 0.06693
# iteration: 16500
# train_loss: 0.003424, test_loss: 0.03563
# train_error: 0.03822, test_error: 0.07442
# iteration: 16600
# train_loss: 0.02031, test_loss: 0.02846
# train_error: 0.08539, test_error: 0.08454
# iteration: 16700
# train_loss: 0.01559, test_loss: 0.08728
# train_error: 0.06737, test_error: 0.14
# iteration: 16800
# train_loss: 0.03924, test_loss: 0.0395
# train_error: 0.1113, test_error: 0.1011
# iteration: 16900
# train_loss: 0.009737, test_loss: 0.06866
# train_error: 0.06102, test_error: 0.1167
# iteration: 17000
# train_loss: 0.1213, test_loss: 0.1476
# train_error: 0.1778, test_error: 0.1784
# iteration: 17100
# train_loss: 0.1103, test_loss: 0.1331
# train_error: 0.1639, test_error: 0.1706
# iteration: 17200
# train_loss: 0.00435, test_loss: 0.03177
# train_error: 0.04555, test_error: 0.08035
# iteration: 17300
# train_loss: 0.00137, test_loss: 0.0299
# train_error: 0.02787, test_error: 0.06397
# iteration: 17400
# train_loss: 0.003124, test_loss: 0.02533
# train_error: 0.03289, test_error: 0.06551
# iteration: 17500
# train_loss: 0.0007561, test_loss: 0.02301
# train_error: 0.0205, test_error: 0.05752
# iteration: 17600
# train_loss: 0.04805, test_loss: 0.07275
# train_error: 0.09142, test_error: 0.1084
# iteration: 17700
# train_loss: 0.01005, test_loss: 0.02393
# train_error: 0.05185, test_error: 0.06246
# iteration: 17800
# train_loss: 0.01139, test_loss: 0.03983
# train_error: 0.06468, test_error: 0.08799
# iteration: 17900
# train_loss: 0.06309, test_loss: 0.09786
# train_error: 0.16, test_error: 0.1707
# iteration: 18000
# train_loss: 0.02684, test_loss: 0.08087
# train_error: 0.09322, test_error: 0.1285
# iteration: 18100
# train_loss: 0.001488, test_loss: 0.01737
# train_error: 0.02791, test_error: 0.05723
# iteration: 18200
# train_loss: 0.0007739, test_loss: 0.01987
# train_error: 0.02108, test_error: 0.05468
# iteration: 18300
# train_loss: 0.007184, test_loss: 0.08923
# train_error: 0.04811, test_error: 0.1001
# iteration: 18400
# train_loss: 0.005145, test_loss: 0.02099
# train_error: 0.04739, test_error: 0.06455
# iteration: 18500
# train_loss: 0.01418, test_loss: 0.05835
# train_error: 0.08006, test_error: 0.1138
# iteration: 18600
# train_loss: 0.004293, test_loss: 0.02669
# train_error: 0.03868, test_error: 0.06571
# iteration: 18700
# train_loss: 0.0224, test_loss: 0.1696
# train_error: 0.09234, test_error: 0.1252
# iteration: 18800
# train_loss: 0.008145, test_loss: 0.02788
# train_error: 0.05563, test_error: 0.08406
# iteration: 18900
# train_loss: 0.007976, test_loss: 0.02619
# train_error: 0.06024, test_error: 0.06608
# iteration: 19000
# train_loss: 0.01912, test_loss: 0.05985
# train_error: 0.08706, test_error: 0.1007
# iteration: 19100
# train_loss: 0.009691, test_loss: 0.03253
# train_error: 0.0583, test_error: 0.07624
# iteration: 19200
# train_loss: 0.002793, test_loss: 0.02155
# train_error: 0.03847, test_error: 0.05992
# iteration: 19300
# train_loss: 0.0006892, test_loss: 0.01705
# train_error: 0.01952, test_error: 0.05006
# iteration: 19400
# train_loss: 0.001703, test_loss: 0.02245
# train_error: 0.02849, test_error: 0.06106
# iteration: 19500
# train_loss: 0.00215, test_loss: 0.02148
# train_error: 0.03123, test_error: 0.06239
# iteration: 19600
# train_loss: 0.001756, test_loss: 0.02046
# train_error: 0.02976, test_error: 0.05667
# iteration: 19700
# train_loss: 0.003299, test_loss: 0.02282
# train_error: 0.03087, test_error: 0.05701
# iteration: 19800
# train_loss: 0.008511, test_loss: 0.0393
# train_error: 0.05753, test_error: 0.08804
# iteration: 19900
# train_loss: 0.02077, test_loss: 0.05716
# train_error: 0.08568, test_error: 0.1168
# iteration: 20000
# train_loss: 0.0426, test_loss: 0.2133
# train_error: 0.1416, test_error: 0.2247
# iteration: 20100
# train_loss: 0.03888, test_loss: 0.05878
# train_error: 0.1168, test_error: 0.1328
# iteration: 20200
# train_loss: 0.001634, test_loss: 0.022
# train_error: 0.02759, test_error: 0.06769
# iteration: 20300
# train_loss: 0.002423, test_loss: 0.02367
# train_error: 0.03447, test_error: 0.05841
# iteration: 20400
# train_loss: 0.001625, test_loss: 0.01843
# train_error: 0.0291, test_error: 0.05677
# iteration: 20500
# train_loss: 0.001225, test_loss: 0.02172
# train_error: 0.02386, test_error: 0.05274
# iteration: 20600
# train_loss: 0.001073, test_loss: 0.01923
# train_error: 0.0246, test_error: 0.05026
# iteration: 20700
# train_loss: 0.0007779, test_loss: 0.02304
# train_error: 0.01956, test_error: 0.05331
# iteration: 20800
# train_loss: 0.003506, test_loss: 0.02168
# train_error: 0.03706, test_error: 0.0673
# iteration: 20900
# train_loss: 0.04653, test_loss: 0.0688
# train_error: 0.09975, test_error: 0.1151
# iteration: 21000
# train_loss: 0.03182, test_loss: 0.08232
# train_error: 0.1005, test_error: 0.138
# iteration: 21100
# train_loss: 0.006291, test_loss: 0.03315
# train_error: 0.05069, test_error: 0.07582
# iteration: 21200
# train_loss: 0.001397, test_loss: 0.02301
# train_error: 0.02684, test_error: 0.05898
# iteration: 21300
# train_loss: 0.0009886, test_loss: 0.01978
# train_error: 0.02369, test_error: 0.05094
# iteration: 21400
# train_loss: 0.001497, test_loss: 0.03373
# train_error: 0.02674, test_error: 0.06832
# iteration: 21500
# train_loss: 0.01067, test_loss: 0.03531
# train_error: 0.06055, test_error: 0.07604
# iteration: 21600
# train_loss: 0.02046, test_loss: 0.05098
# train_error: 0.0877, test_error: 0.1081
# iteration: 21700
# train_loss: 0.01729, test_loss: 0.03719
# train_error: 0.07404, test_error: 0.08581
# iteration: 21800
# train_loss: 0.01225, test_loss: 0.02992
# train_error: 0.05796, test_error: 0.06684
# iteration: 21900
# train_loss: 0.002125, test_loss: 0.01884
# train_error: 0.03069, test_error: 0.05451
# iteration: 22000
# train_loss: 0.004526, test_loss: 0.0198
# train_error: 0.04396, test_error: 0.06068
# iteration: 22100
# train_loss: 0.002068, test_loss: 0.0226
# train_error: 0.03006, test_error: 0.06227
# iteration: 22200
# train_loss: 0.01523, test_loss: 0.09004
# train_error: 0.07373, test_error: 0.1388
# iteration: 22300
# train_loss: 0.006263, test_loss: 0.02906
# train_error: 0.05461, test_error: 0.08256
# iteration: 22400
# train_loss: 0.004178, test_loss: 0.02727
# train_error: 0.0408, test_error: 0.07578
# iteration: 22500
# train_loss: 0.001505, test_loss: 0.01843
# train_error: 0.02637, test_error: 0.05592
# iteration: 22600
# train_loss: 0.005797, test_loss: 0.02643
# train_error: 0.04548, test_error: 0.07136
# iteration: 22700
# train_loss: 0.001096, test_loss: 0.01538
# train_error: 0.02418, test_error: 0.05434
# iteration: 22800
# train_loss: 0.001178, test_loss: 0.0201
# train_error: 0.02289, test_error: 0.05264
# iteration: 22900
# train_loss: 0.001538, test_loss: 0.01861
# train_error: 0.02575, test_error: 0.05195
# iteration: 23000
# train_loss: 0.001139, test_loss: 0.01454
# train_error: 0.02319, test_error: 0.04761
# iteration: 23100
# train_loss: 0.01796, test_loss: 0.05541
# train_error: 0.09164, test_error: 0.1243
# iteration: 23200
# train_loss: 0.3308, test_loss: 0.2993
# train_error: 0.2695, test_error: 0.2511
# iteration: 23300
# train_loss: 0.01232, test_loss: 0.0406
# train_error: 0.0749, test_error: 0.1001
# iteration: 23400
# train_loss: 0.003639, test_loss: 0.02589
# train_error: 0.03825, test_error: 0.06302
# iteration: 23500
# train_loss: 0.001983, test_loss: 0.02794
# train_error: 0.02908, test_error: 0.06741
# iteration: 23600
# train_loss: 0.004284, test_loss: 0.02047
# train_error: 0.0431, test_error: 0.05845
# iteration: 23700
# train_loss: 0.03393, test_loss: 0.05677
# train_error: 0.0916, test_error: 0.09936
# iteration: 23800
# train_loss: 0.01279, test_loss: 0.04374
# train_error: 0.06629, test_error: 0.09935
# iteration: 23900
# train_loss: 0.006794, test_loss: 0.03353
# train_error: 0.05238, test_error: 0.0766
# iteration: 24000
# train_loss: 0.002803, test_loss: 0.02684
# train_error: 0.03565, test_error: 0.08244
# iteration: 24100
# train_loss: 0.006501, test_loss: 0.02218
# train_error: 0.04791, test_error: 0.06574
# iteration: 24200
# train_loss: 0.001064, test_loss: 0.01397
# train_error: 0.0207, test_error: 0.05265
# iteration: 24300
# train_loss: 0.09297, test_loss: 0.1238
# train_error: 0.1822, test_error: 0.1595
# iteration: 24400
# train_loss: 0.004998, test_loss: 0.02238
# train_error: 0.04566, test_error: 0.06796
# iteration: 24500
# train_loss: 0.001598, test_loss: 0.01978
# train_error: 0.02354, test_error: 0.05736
# iteration: 24600
# train_loss: 0.001771, test_loss: 0.01807
# train_error: 0.02926, test_error: 0.05708
# iteration: 24700
# train_loss: 0.002031, test_loss: 0.01923
# train_error: 0.02601, test_error: 0.05619
# iteration: 24800
# train_loss: 0.0008906, test_loss: 0.01926
# train_error: 0.02068, test_error: 0.0594
# iteration: 24900
# train_loss: 0.002401, test_loss: 0.01663
# train_error: 0.034, test_error: 0.05432
# iteration: 25000
# train_loss: 0.009206, test_loss: 0.05501
# train_error: 0.0689, test_error: 0.1036
# iteration: 25100
# train_loss: 0.005599, test_loss: 0.02217
# train_error: 0.04448, test_error: 0.06855
# iteration: 25200
# train_loss: 0.004795, test_loss: 0.01637
# train_error: 0.03855, test_error: 0.0525
# iteration: 25300
# train_loss: 0.001081, test_loss: 0.01608
# train_error: 0.02201, test_error: 0.04861
# iteration: 25400
# train_loss: 0.0008113, test_loss: 0.0147
# train_error: 0.01942, test_error: 0.04678
# iteration: 25500
# train_loss: 0.003224, test_loss: 0.02985
# train_error: 0.04039, test_error: 0.07857
# iteration: 25600
# train_loss: 0.002195, test_loss: 0.02137
# train_error: 0.03269, test_error: 0.06926
# iteration: 25700
# train_loss: 0.005986, test_loss: 0.02716
# train_error: 0.04928, test_error: 0.06764
# iteration: 25800
# train_loss: 0.004372, test_loss: 0.02921
# train_error: 0.03666, test_error: 0.06906
# iteration: 25900
# train_loss: 0.00259, test_loss: 0.0187
# train_error: 0.03347, test_error: 0.06155
# iteration: 26000
# train_loss: 0.00502, test_loss: 0.01563
# train_error: 0.04755, test_error: 0.05759
# iteration: 26100
# train_loss: 0.001832, test_loss: 0.01522
# train_error: 0.025, test_error: 0.05086
# iteration: 26200
# train_loss: 0.004874, test_loss: 0.01541
# train_error: 0.04439, test_error: 0.05891
# iteration: 26300
# train_loss: 0.0633, test_loss: 0.07428
# train_error: 0.1177, test_error: 0.1366
# iteration: 26400
# train_loss: 0.04836, test_loss: 0.07544
# train_error: 0.1363, test_error: 0.1466
# iteration: 26500
# train_loss: 0.02077, test_loss: 0.03939
# train_error: 0.0883, test_error: 0.1053
# iteration: 26600
# train_loss: 0.002242, test_loss: 0.03829
# train_error: 0.03105, test_error: 0.07483
# iteration: 26700
# train_loss: 0.01951, test_loss: 0.07018
# train_error: 0.06038, test_error: 0.09395
# iteration: 26800
# train_loss: 0.02129, test_loss: 0.06996
# train_error: 0.09416, test_error: 0.1248
# iteration: 26900
# train_loss: 0.00432, test_loss: 0.03741
# train_error: 0.04121, test_error: 0.07388
# iteration: 27000
# train_loss: 0.002117, test_loss: 0.02143
# train_error: 0.02686, test_error: 0.05691
# iteration: 27100
# train_loss: 0.008096, test_loss: 0.02953
# train_error: 0.04266, test_error: 0.06595
# iteration: 27200
# train_loss: 0.004938, test_loss: 0.02678
# train_error: 0.04512, test_error: 0.07051
# iteration: 27300
# train_loss: 0.0009613, test_loss: 0.01632
# train_error: 0.02052, test_error: 0.05366
# iteration: 27400
# train_loss: 0.003058, test_loss: 0.01278
# train_error: 0.03877, test_error: 0.05589
# iteration: 27500
# train_loss: 0.005402, test_loss: 0.02933
# train_error: 0.04777, test_error: 0.07738
# iteration: 27600
# train_loss: 0.09141, test_loss: 0.1346
# train_error: 0.1595, test_error: 0.1694
# iteration: 27700
# train_loss: 0.01478, test_loss: 0.03211
# train_error: 0.08583, test_error: 0.09137
# iteration: 27800
# train_loss: 0.0094, test_loss: 0.07511
# train_error: 0.05977, test_error: 0.1071
# iteration: 27900
# train_loss: 0.01287, test_loss: 0.0528
# train_error: 0.07624, test_error: 0.1184
# iteration: 28000
# train_loss: 0.004753, test_loss: 0.05807
# train_error: 0.04641, test_error: 0.09505
# iteration: 28100
# train_loss: 0.005383, test_loss: 0.0231
# train_error: 0.04707, test_error: 0.0709
# iteration: 28200
# train_loss: 0.001474, test_loss: 0.01907
# train_error: 0.02687, test_error: 0.05815
# iteration: 28300
# train_loss: 0.001102, test_loss: 0.0171
# train_error: 0.02421, test_error: 0.05037
# iteration: 28400
# train_loss: 0.003194, test_loss: 0.01666
# train_error: 0.03729, test_error: 0.05376
# iteration: 28500
# train_loss: 0.00682, test_loss: 0.0254
# train_error: 0.05056, test_error: 0.0748
# iteration: 28600
# train_loss: 0.003563, test_loss: 0.01875
# train_error: 0.03496, test_error: 0.05528
# iteration: 28700
# train_loss: 0.001368, test_loss: 0.01466
# train_error: 0.02575, test_error: 0.04976
# iteration: 28800
# train_loss: 0.001175, test_loss: 0.01824
# train_error: 0.0248, test_error: 0.052
# iteration: 28900
# train_loss: 0.0007446, test_loss: 0.02718
# train_error: 0.01908, test_error: 0.0578
# iteration: 29000
# train_loss: 0.006984, test_loss: 0.03387
# train_error: 0.04361, test_error: 0.06327
# iteration: 29100
# train_loss: 0.132, test_loss: 0.213
# train_error: 0.1996, test_error: 0.1963
# iteration: 29200
# train_loss: 0.01127, test_loss: 0.03977
# train_error: 0.06274, test_error: 0.08929
# iteration: 29300
# train_loss: 0.003428, test_loss: 0.0201
# train_error: 0.04099, test_error: 0.06487
# iteration: 29400
# train_loss: 0.002403, test_loss: 0.01983
# train_error: 0.03201, test_error: 0.06102
# iteration: 29500
# train_loss: 0.0008637, test_loss: 0.01939
# train_error: 0.01837, test_error: 0.0536
# iteration: 29600
# train_loss: 0.0009253, test_loss: 0.01877
# train_error: 0.02151, test_error: 0.05095
# iteration: 29700
# train_loss: 0.001227, test_loss: 0.01824
# train_error: 0.02001, test_error: 0.04988
# iteration: 29800
# train_loss: 0.0005142, test_loss: 0.01763
# train_error: 0.01591, test_error: 0.04739
# iteration: 29900
# train_loss: 0.0005391, test_loss: 0.01659
# train_error: 0.01591, test_error: 0.04678
# iteration: 30000
# train_loss: 0.02194, test_loss: 0.04605
# train_error: 0.07052, test_error: 0.07795
# iteration: 30100
# train_loss: 0.004327, test_loss: 0.02302
# train_error: 0.04491, test_error: 0.07116
# iteration: 30200
# train_loss: 0.007423, test_loss: 0.03089
# train_error: 0.05265, test_error: 0.07867
# iteration: 30300
# train_loss: 0.01016, test_loss: 0.03357
# train_error: 0.06579, test_error: 0.07951
# iteration: 30400
# train_loss: 0.003346, test_loss: 0.01874
# train_error: 0.04086, test_error: 0.06331
# iteration: 30500
# train_loss: 0.002127, test_loss: 0.01925
# train_error: 0.02976, test_error: 0.05889
# iteration: 30600
# train_loss: 0.01456, test_loss: 0.04429
# train_error: 0.05696, test_error: 0.102
# iteration: 30700
# train_loss: 0.008116, test_loss: 0.04514
# train_error: 0.0445, test_error: 0.09898
# iteration: 30800
# train_loss: 0.001484, test_loss: 0.02166
# train_error: 0.02759, test_error: 0.06793
# iteration: 30900
# train_loss: 0.004514, test_loss: 0.0473
# train_error: 0.03801, test_error: 0.08628
# iteration: 31000
# train_loss: 0.02131, test_loss: 0.1009
# train_error: 0.0675, test_error: 0.111
# iteration: 31100
# train_loss: 0.002395, test_loss: 0.02834
# train_error: 0.03493, test_error: 0.07487
# iteration: 31200
# train_loss: 0.00502, test_loss: 0.0242
# train_error: 0.03838, test_error: 0.06457
# iteration: 31300
# train_loss: 0.01699, test_loss: 0.07108
# train_error: 0.06717, test_error: 0.1041
# iteration: 31400
# train_loss: 0.004246, test_loss: 0.02169
# train_error: 0.04013, test_error: 0.0585
# iteration: 31500
# train_loss: 0.002852, test_loss: 0.01818
# train_error: 0.03117, test_error: 0.052
# iteration: 31600
# train_loss: 0.004118, test_loss: 0.02152
# train_error: 0.03774, test_error: 0.06729
# iteration: 31700
# train_loss: 0.005585, test_loss: 0.04295
# train_error: 0.0495, test_error: 0.08948
# iteration: 31800
# train_loss: 0.02376, test_loss: 0.03349
# train_error: 0.09124, test_error: 0.08376
# iteration: 31900
# train_loss: 0.004757, test_loss: 0.06035
# train_error: 0.039, test_error: 0.09643
# iteration: 32000
# train_loss: 0.04644, test_loss: 0.04608
# train_error: 0.1194, test_error: 0.1113
# iteration: 32100
# train_loss: 0.003588, test_loss: 0.02393
# train_error: 0.03912, test_error: 0.07155
# iteration: 32200
# train_loss: 0.001261, test_loss: 0.02061
# train_error: 0.02406, test_error: 0.0496
# iteration: 32300
# train_loss: 0.003511, test_loss: 0.03277
# train_error: 0.04257, test_error: 0.06774
# iteration: 32400
# train_loss: 0.007702, test_loss: 0.03549
# train_error: 0.05152, test_error: 0.08063
# iteration: 32500
# train_loss: 0.02731, test_loss: 0.04687
# train_error: 0.07898, test_error: 0.09553
# iteration: 32600
# train_loss: 0.001302, test_loss: 0.02052
# train_error: 0.02485, test_error: 0.05764
# iteration: 32700
# train_loss: 0.003876, test_loss: 0.02157
# train_error: 0.04161, test_error: 0.06112
# iteration: 32800
# train_loss: 0.0009951, test_loss: 0.0179
# train_error: 0.02047, test_error: 0.05143
# iteration: 32900
# train_loss: 0.00112, test_loss: 0.01792
# train_error: 0.01958, test_error: 0.04968
# iteration: 33000
# train_loss: 0.0008092, test_loss: 0.01915
# train_error: 0.01853, test_error: 0.04978
# iteration: 33100
# train_loss: 0.000649, test_loss: 0.0185
# train_error: 0.01755, test_error: 0.04876
# iteration: 33200
# train_loss: 0.0003511, test_loss: 0.01698
# train_error: 0.01331, test_error: 0.0443
# iteration: 33300
# train_loss: 0.0009942, test_loss: 0.01802
# train_error: 0.01991, test_error: 0.04671
# iteration: 33400
# train_loss: 0.0005506, test_loss: 0.01798
# train_error: 0.01549, test_error: 0.04566
# iteration: 33500
# train_loss: 0.003214, test_loss: 0.0354
# train_error: 0.04004, test_error: 0.07562
# iteration: 33600
# train_loss: 0.006211, test_loss: 0.02789
# train_error: 0.05261, test_error: 0.08277
# iteration: 33700
# train_loss: 0.01641, test_loss: 0.04304
# train_error: 0.07363, test_error: 0.1038
# iteration: 33800
# train_loss: 0.03525, test_loss: 0.08203
# train_error: 0.1062, test_error: 0.1394
# iteration: 33900
# train_loss: 0.03312, test_loss: 0.08044
# train_error: 0.1303, test_error: 0.1572
# iteration: 34000
# train_loss: 0.002082, test_loss: 0.0277
# train_error: 0.03489, test_error: 0.06986
# iteration: 34100
# train_loss: 0.001606, test_loss: 0.01779
# train_error: 0.03141, test_error: 0.05355
# iteration: 34200
# train_loss: 0.001326, test_loss: 0.02187
# train_error: 0.02571, test_error: 0.05777
# iteration: 34300
# train_loss: 0.001523, test_loss: 0.01908
# train_error: 0.02647, test_error: 0.05022
# iteration: 34400
# train_loss: 0.001054, test_loss: 0.01784
# train_error: 0.02308, test_error: 0.04943
# iteration: 34500
# train_loss: 0.001575, test_loss: 0.01945
# train_error: 0.02675, test_error: 0.05404
# iteration: 34600
# train_loss: 0.001007, test_loss: 0.0207
# train_error: 0.02313, test_error: 0.05309
# iteration: 34700
# train_loss: 0.006115, test_loss: 0.02812
# train_error: 0.04886, test_error: 0.0648
# iteration: 34800
# train_loss: 0.0004166, test_loss: 0.01896
# train_error: 0.01496, test_error: 0.04981
# iteration: 34900
# train_loss: 0.002522, test_loss: 0.01727
# train_error: 0.03305, test_error: 0.05822
# iteration: 35000
# train_loss: 0.01066, test_loss: 0.02674
# train_error: 0.05821, test_error: 0.07473
# iteration: 35100
# train_loss: 0.01357, test_loss: 0.1138
# train_error: 0.07633, test_error: 0.1412
# iteration: 35200
# train_loss: 0.006778, test_loss: 0.02015
# train_error: 0.05255, test_error: 0.06896
# iteration: 35300
# train_loss: 0.001992, test_loss: 0.02303
# train_error: 0.03274, test_error: 0.06111
# iteration: 35400
# train_loss: 0.03452, test_loss: 0.0566
# train_error: 0.1119, test_error: 0.1298
# iteration: 35500
# train_loss: 0.003141, test_loss: 0.01681
# train_error: 0.03551, test_error: 0.06482
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train()
#
# Cell In[6], line 40, in train()
#      38 # update parameters
#      39 optimizer.zero_grad()
# ---> 40 loss_train.backward()
#      41 optimizer.step()
#      43 iteration += 1
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\torch\_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# 过拟合
# MSEloss curve
Len = len(losses['loss_train'])
epoch_total = np.linspace(0, Len, Len)
plt.title('MSEloss')
plt.plot(epoch_total, losses['loss_train'],color="black", label='Train_loss')
plt.plot(epoch_total, losses['loss_test'],color="orange", label='Train_loss')
plt.legend(loc='upper right')
plt.xlabel('epoch_total')
plt.ylabel('loss_fn')
plt.show()

# %%
# train or test
bo_len = np.loadtxt(bo_len_path, delimiter=",", dtype=np.float32)

# plot_train_data
c = 14                               # 186
valid_input = train_input[c:c+1]
valid_predict = forward_model(valid_input).view(-1).cpu().detach().numpy().reshape(1, 300)               
valid_label = train_label[c].cpu().detach().numpy().reshape(1, 300)                                    
valid_predict = valid_predict.reshape(300,)
valid_label = valid_label.reshape(300,)
print(valid_input)

plt.title('Comparison of Transmission Spectrum')
plt.plot(bo_len, valid_predict, color="orange", label='Prediction', linestyle='-')
plt.plot(bo_len, valid_label, color="black", label='Simulation', linestyle=':')
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('Fx(10^-12)')
plt.show()

# %%
test_input.shape

# %%
import time
time_start = time.time()  # 记录开始时间

# 测试及画图
c = 36
valid_input = test_input[c:c+1]
print(valid_input)
valid_predict = forward_model(valid_input).view(-1).cpu().detach().numpy().reshape(1, 300)               
valid_label = test_label[c].cpu().detach().numpy().reshape(1, 300)                                    
valid_predict = valid_predict.reshape(300,)
valid_label = valid_label.reshape(300,)

plt.title('Comparison of Transmission Spectrum')
plt.plot(bo_len, valid_predict, color="orange", label='Prediction', linestyle='--')
plt.plot(bo_len, valid_label, color="black", label='Simulation', linestyle=':')
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('Fx(10^-12)')
plt.show()

time_end = time.time()  # 记录结束时间
time_sum = time_end - time_start  # 计算的时间差为程序的执行时间，单位为秒/s
print(time_sum)

# %%
# Save the updated weights file
save_dir = os.path.join(data_root, "weight_optim")
assert os.path.exists(save_dir), "{} path does not exist.".format(save_dir)
# Save the weight_optim
torch.save(forward_model, save_dir + '\model_train_Fx'  + '.pt')

# %% [raw]
# # 数据补充保存--测试集c=36的数据
# test_36 = np.zeros((300, 3))
# test_36[:, 0] = bo_len
# test_36[:, 1] = valid_label        # 真实值
# test_36[:, 2] = valid_predict      # 预测值
# np.savetxt("Fx.csv", test_36, delimiter=',')
